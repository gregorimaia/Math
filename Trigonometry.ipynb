# %% [markdown]
# <a href="https://colab.research.google.com/github/gregorimaia/Math/blob/main/Trigonometry.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Random Numbers**

# %%
import numpy as np
import matplotlib.pyplot as plt

#Normaly distributed numbers
NumbN = np.random.randn(200)
#Uniform distributed numbers
Numb = np.random.rand(200)


plt.subplot(121)
plt.plot(NumbN,'-')
plt.axis('square')
plt.title('Normaly distributed numbers')
plt.axis([0,20,-5,5])
plt.grid()
plt.subplot(122)
plt.plot(Numb)
plt.axis('square')
plt.title('Uniform distributed numbers')
plt.axis([0,20,-5,5])
plt.grid()

plt.show()

# %% [markdown]
# #**Converting between radians and degrees**

# %%
import numpy as np

deg = 720

#rad = deg*np.pi/180
#rad = rad%(2*np.pi)

rad = np.deg2rad(deg)%(2*np.pi)

print('%g degrees is %g radians.' %(deg,rad))
# Out:
# 720 degrees is 0 radians.

# %%
rad = np.pi

#deg = (180*rad/np.pi)%360
deg = np.rad2deg(rad)
print('%g radians is %g degrees.' %(rad,deg))
# Out:
# 3.14159 radians is 180 degrees.

# %% [markdown]
# #**The Pythagorean theorem**

# %%
import numpy as np
import matplotlib.pyplot as plt

a = 4
b = 3

c = np.sqrt(a**2 + b**2)

plt.plot([0,a],[0,0],'k',linewidth=2)
plt.plot([0,0],[0,b],'k',linewidth=2)
plt.plot([0,a],[b,0],'k',linewidth=2)
plt.plot([.3,.3],[0,.3],'k',linewidth=2)
plt.plot([0,.3],[.3,.3],'k',linewidth=2)

plt.text(a/3,-.30,'a='+str(a),fontsize=15)
plt.text(.1,b/3,'b='+str(b),fontsize=15)
plt.text(a/2+.1,b/2,'c='+str(c),fontsize=15)

plt.axis('square')
axlim = np.max((a,b)) +.5
plt.axis([-.5,axlim,-.5,axlim])
plt.grid()
plt.show()

# %% [markdown]
# #**Graphing sine, cossine, and tangent**

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(0,6*np.pi,400)
th = np.linspace(0,4*np.pi,100)

plt.subplot(121)
plt.plot(x,np.sin(x),'r',label='$sin(\\theta)$')
plt.plot(x,np.cos(x),'b',label='$cos(\\theta)$')
plt.xlabel('rad')
plt.ylabel('function value')

plt.subplot(122)
plt.xlabel('rad')
plt.plot(th,np.tan(th),'k',label='$tan(\\theta)$')


plt.legend()
plt.show()
